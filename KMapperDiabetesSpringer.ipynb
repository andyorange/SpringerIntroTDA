# %%
from pandas import DataFrame  # Pandas hat einen enormen memory foorprint, daher nur das Notwendige laden
import kmapper as km

# Preprocessing and clustering
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
from sklearn.datasets import load_diabetes

# %% [markdown]
# ### Dataset {-}

# %%
# Wir nutzen den öffentlichen Diabetes Datensatz
data_diabetes = load_diabetes()

# %%
X = data_diabetes.data
Y = data_diabetes.target

# %%
dfX = pd.DataFrame(data_diabetes.data, columns=data_diabetes.feature_names)

# %%
# Vorbereitende Skalierung der Daten
scaler = StandardScaler()
data = scaler.fit_transform(X)

# %%
mapper = km.KeplerMapper(verbose=2)

# %%
mapped_data = mapper.fit_transform(X)

# %%
graph = mapper.map(
    mapped_data, X,
    clusterer=DBSCAN(eps=0.1, min_samples=5),
    cover=km.Cover(n_cubes=16, perc_overlap=0.2),
)

# %%
mapper.visualize(graph, title='Diabetes Clustering', path_html="kmapper_diabetes_clustering.html")
